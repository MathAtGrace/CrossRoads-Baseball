# %%
import pickle
import pandas as pd
pkl_file = open('Grace.pkl', 'rb')

# %%
dfb = pickle.load(pkl_file)

# %%
dfb
# Out:
#                   Batting  GP  GS    AVG   AB    R    H  2B  3B  HR  ...  \
# 0          Griffin, Chris  26  25  0.390   82   18   32   4   4   4  ...
# 1        Enyart, Mitchell  23  22  0.352   71   11   25   4   0   1  ...
# 2          Harris, Xavier  27  27  0.337   86   19   29   3   0   0  ...
# 3             Elford, Sid  18   8  0.333   36    5   12   2   0   1  ...
# 4          Haney, Houston  24  23  0.321   78    8   25   7   0   2  ...
# 5         Anderson, David  25  25  0.312  109   14   34   6   2   0  ...
# 6           Brooks, Ethan  17  10  0.294   34    7   10   0   1   3  ...
# 7              Snyder, RJ  25  15  0.288   59   21   17   2   0   1  ...
# 8             Sapp, Jacob  25  23  0.277   65    2   18   4   0   1  ...
# 9            Newkirk, Sam  26  25  0.236   89   15   21   2   2   1  ...
# 10         Mullett, Jaron  20  11  0.231   39   12    9   2   1   0  ...
# 11       Ackerman, Hunter  23  19  0.222   63   15   14   2   0   0  ...
# ...
